# %% [markdown]
# <a href="https://colab.research.google.com/github/PytonDS/DS-Bootcamp-Udemy-KrakowiakP/blob/main/Pandas_02_dane_gieldowe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Danych

# %%
import numpy as np
import pandas as pd

# %%
def fetch_financial_data(company='AMZN'):
    """Pobiera dane dotyczące notowań spółek na giełdzie według symboli na serwisie stooq.pl"""
    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source='stooq')

df = fetch_financial_data()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1257 entries, 2023-03-15 to 2018-03-19
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1257 non-null   float64
#  1   High    1257 non-null   float64
#  2   Low     1257 non-null   float64
#  3   Close   1257 non-null   float64
#  4   Volume  1257 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 58.9 KB

# %%
df.head(6)
# Out:
#              Open    High     Low  Close    Volume
# Date
# 2023-03-15  93.22  96.670  93.070  96.20  70731792
# 2023-03-14  93.83  95.070  92.710  94.88  60912674
# 2023-03-13  89.97  94.020  88.120  92.43  72397053
# 2023-03-10  92.67  93.570  90.245  90.73  69827490
# 2023-03-09  93.68  96.210  92.180  92.25  56218705
# 2023-03-08  93.60  94.165  92.180  93.92  44899128

# %%
df.columns = [col.lower() for col in df.columns]
df.head()
# Out:
#              open   high     low  close    volume
# Date
# 2023-03-15  93.22  96.67  93.070  96.20  70731792
# 2023-03-14  93.83  95.07  92.710  94.88  60912674
# 2023-03-13  89.97  94.02  88.120  92.43  72397053
# 2023-03-10  92.67  93.57  90.245  90.73  69827490
# 2023-03-09  93.68  96.21  92.180  92.25  56218705

# %%
round(df.describe().T, 1)
# Out:
#          count        mean         std         min         25%         50%  \
# open    1257.0       121.0        34.6        67.3        90.3       108.1
# high    1257.0       122.4        34.9        69.8        91.2       111.0
# low     1257.0       119.3        34.2        65.4        89.2       106.4
# close   1257.0       120.9        34.5        67.2        90.3       108.4
# volume  1257.0  84866685.4  39572514.4  17626740.0  58217760.0  73140540.0
#
#                75%          max
# open         158.3        187.2
# high         159.9        188.7
# low          156.2        184.8
# close        158.1        186.6
# volume  99533072.0  311345660.0

# %%
df.head(10)
# Out:
#              open    high     low  close    volume
# Date
# 2023-03-15  93.22  96.670  93.070  96.20  70731792
# 2023-03-14  93.83  95.070  92.710  94.88  60912674
# 2023-03-13  89.97  94.020  88.120  92.43  72397053
# 2023-03-10  92.67  93.570  90.245  90.73  69827490
# 2023-03-09  93.68  96.210  92.180  92.25  56218705
# 2023-03-08  93.60  94.165  92.180  93.92  44899128
# 2023-03-07  94.06  95.090  92.780  93.55  49100668
# 2023-03-06  95.19  96.545  93.740  93.75  52112355
# 2023-03-03  92.74  94.940  92.660  94.90  55759609
# 2023-03-02  91.41  92.230  90.390  92.13  55574820

# %%
df[['open', 'close']]
# Out:
#                open    close
# Date
# 2023-03-15  93.2200  96.2000
# 2023-03-14  93.8300  94.8800
# 2023-03-13  89.9700  92.4300
# 2023-03-10  92.6700  90.7300
# 2023-03-09  93.6800  92.2500
# ...             ...      ...
# 2018-03-23  76.9505  74.7780
# 2018-03-22  78.2735  77.2460
# 2018-03-21  79.3225  79.0930
# 2018-03-20  77.5170  79.3255
# 2018-03-19  77.7265  77.2465
#
# [1257 rows x 2 columns]

# %%
df.iloc[:, [0, 3]]
# Out:
#                open    close
# Date
# 2023-03-15  93.2200  96.2000
# 2023-03-14  93.8300  94.8800
# 2023-03-13  89.9700  92.4300
# 2023-03-10  92.6700  90.7300
# 2023-03-09  93.6800  92.2500
# ...             ...      ...
# 2018-03-23  76.9505  74.7780
# 2018-03-22  78.2735  77.2460
# 2018-03-21  79.3225  79.0930
# 2018-03-20  77.5170  79.3255
# 2018-03-19  77.7265  77.2465
#
# [1257 rows x 2 columns]

# %%
df.index
# Out:
# DatetimeIndex(['2023-03-15', '2023-03-14', '2023-03-13', '2023-03-10',
#                '2023-03-09', '2023-03-08', '2023-03-07', '2023-03-06',
#                '2023-03-03', '2023-03-02',
#                ...
#                '2018-04-02', '2018-03-29', '2018-03-28', '2018-03-27',
#                '2018-03-26', '2018-03-23', '2018-03-22', '2018-03-21',
#                '2018-03-20', '2018-03-19'],
#               dtype='datetime64[ns]', name='Date', length=1257, freq=None)

# %%
df.loc[['2023-03-15', '2023-03-13']]
# Out:
#              open   high    low  close    volume
# Date
# 2023-03-15  93.22  96.67  93.07  96.20  70731792
# 2023-03-13  89.97  94.02  88.12  92.43  72397053

# %% [markdown]
# ## CZ. II
# Obliczanie nowych kolumn

# %%
df = fetch_financial_data('UBER')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 969 entries, 2023-03-15 to 2019-05-10
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    969 non-null    float64
#  1   High    969 non-null    float64
#  2   Low     969 non-null    float64
#  3   Close   969 non-null    float64
#  4   Volume  969 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 45.4 KB

# %%
df.describe()
# Out:
#              Open        High         Low       Close        Volume
# count  969.000000  969.000000  969.000000  969.000000  9.690000e+02
# mean    37.170272   37.935618   36.335021   37.134696  2.556535e+07
# std      9.706238    9.779773    9.551569    9.645089  1.651590e+07
# min     15.960000   17.800000   13.710000   14.820000  3.380003e+06
# 25%     29.900000   30.490000   29.270000   29.990000  1.578786e+07
# 50%     34.520000   35.140000   33.820000   34.540000  2.195069e+07
# 75%     44.060000   44.720000   43.210000   43.860000  3.072537e+07
# max     63.250000   64.050000   60.800000   63.180000  1.863225e+08

# %%
df.head()
# Out:
#               Open    High     Low  Close    Volume
# Date
# 2023-03-15  31.830  32.235  31.385  31.97  28434860
# 2023-03-14  32.940  33.420  32.160  32.36  34241847
# 2023-03-13  30.585  31.085  29.970  30.82  24302644
# 2023-03-10  32.000  32.035  30.770  31.11  32553607
# 2023-03-09  34.410  34.520  32.280  32.32  27629682

# %%
df['Average'] = (df['Open'] + df['Close']) / 2
df.head()
# Out:
#               Open    High     Low  Close    Volume  Average
# Date
# 2023-03-15  31.830  32.235  31.385  31.97  28434860  31.9000
# 2023-03-14  32.940  33.420  32.160  32.36  34241847  32.6500
# 2023-03-13  30.585  31.085  29.970  30.82  24302644  30.7025
# 2023-03-10  32.000  32.035  30.770  31.11  32553607  31.5550
# 2023-03-09  34.410  34.520  32.280  32.32  27629682  33.3650

# %%
df.sort_index(inplace=True)

# %%
df.head()
# Out:
#              Open   High    Low  Close     Volume  Average
# Date
# 2019-05-10  42.00  45.00  41.06  41.57  186322536   41.785
# 2019-05-13  38.79  39.24  36.08  37.10   79442420   37.945
# 2019-05-14  38.31  39.96  36.85  39.96   46661147   39.135
# 2019-05-15  39.37  41.88  38.95  41.29   36086065   40.330
# 2019-05-16  41.48  44.06  41.25  43.00   38115524   42.240

# %%
df[['Close']].shift(1)
# Out:
#             Close
# Date
# 2019-05-10    NaN
# 2019-05-13  41.57
# 2019-05-14  37.10
# 2019-05-15  39.96
# 2019-05-16  41.29
# ...           ...
# 2023-03-09  34.01
# 2023-03-10  32.32
# 2023-03-13  31.11
# 2023-03-14  30.82
# 2023-03-15  32.36
#
# [969 rows x 1 columns]

# %%
df['Close_shift'] = df['Close'].shift(1)

# %%
df
# Out:
#               Open    High     Low  Close     Volume  Average  Close_shift
# Date
# 2019-05-10  42.000  45.000  41.060  41.57  186322536  41.7850          NaN
# 2019-05-13  38.790  39.240  36.080  37.10   79442420  37.9450        41.57
# 2019-05-14  38.310  39.960  36.850  39.96   46661147  39.1350        37.10
# 2019-05-15  39.370  41.880  38.950  41.29   36086065  40.3300        39.96
# 2019-05-16  41.480  44.060  41.250  43.00   38115524  42.2400        41.29
# ...            ...     ...     ...    ...        ...      ...          ...
# 2023-03-09  34.410  34.520  32.280  32.32   27629682  33.3650        34.01
# 2023-03-10  32.000  32.035  30.770  31.11   32553607  31.5550        32.32
# 2023-03-13  30.585  31.085  29.970  30.82   24302644  30.7025        31.11
# 2023-03-14  32.940  33.420  32.160  32.36   34241847  32.6500        30.82
# 2023-03-15  31.830  32.235  31.385  31.97   28434860  31.9000        32.36
#
# [969 rows x 7 columns]

# %%
df['Daily_Change'] = df.Close / df.Close_shift - 1
df.head()
# Out:
#              Open   High    Low  Close     Volume  Average  Close_shift  \
# Date
# 2019-05-10  42.00  45.00  41.06  41.57  186322536   41.785          NaN
# 2019-05-13  38.79  39.24  36.08  37.10   79442420   37.945        41.57
# 2019-05-14  38.31  39.96  36.85  39.96   46661147   39.135        37.10
# 2019-05-15  39.37  41.88  38.95  41.29   36086065   40.330        39.96
# 2019-05-16  41.48  44.06  41.25  43.00   38115524   42.240        41.29
#
#             Daily_Change
# Date
# 2019-05-10           NaN
# 2019-05-13     -0.107529
# 2019-05-14      0.077089
# 2019-05-15      0.033283
# 2019-05-16      0.041414

# %%
df.drop('Close_shift', axis=1)
# Out:
#               Open    High     Low  Close     Volume  Average  Daily_Change
# Date
# 2019-05-10  42.000  45.000  41.060  41.57  186322536  41.7850           NaN
# 2019-05-13  38.790  39.240  36.080  37.10   79442420  37.9450     -0.107529
# 2019-05-14  38.310  39.960  36.850  39.96   46661147  39.1350      0.077089
# 2019-05-15  39.370  41.880  38.950  41.29   36086065  40.3300      0.033283
# 2019-05-16  41.480  44.060  41.250  43.00   38115524  42.2400      0.041414
# ...            ...     ...     ...    ...        ...      ...           ...
# 2023-03-09  34.410  34.520  32.280  32.32   27629682  33.3650     -0.049691
# 2023-03-10  32.000  32.035  30.770  31.11   32553607  31.5550     -0.037438
# 2023-03-13  30.585  31.085  29.970  30.82   24302644  30.7025     -0.009322
# 2023-03-14  32.940  33.420  32.160  32.36   34241847  32.6500      0.049968
# 2023-03-15  31.830  32.235  31.385  31.97   28434860  31.9000     -0.012052
#
# [969 rows x 7 columns]

# %%
del df['Close_shift']

# %%
df.min()
# Out:
# Open            1.596000e+01
# High            1.780000e+01
# Low             1.371000e+01
# Close           1.482000e+01
# Volume          3.380003e+06
# Average         1.629000e+01
# Daily_Change   -2.162877e-01
# dtype: float64

# %%
df.Daily_Change.max()
# Out:
# 0.3825910931174088

# %%
import seaborn as sns
sns.set()

# %%
df.Daily_Change.hist(bins=50)
# Out:
# <Axes: >

# %%
df.Close.plot(xlabel='Date', ylabel='Price')
# Out:
# <Axes: xlabel='Date', ylabel='Price'>

# %%
df.Close.plot(xlabel='Date', ylabel='Price', kind='box')
# Out:
# <Axes: ylabel='Price'>

# %%
df.Close.describe()
# Out:
# count    969.000000
# mean      37.134696
# std        9.645089
# min       14.820000
# 25%       29.990000
# 50%       34.540000
# 75%       43.860000
# max       63.180000
# Name: Close, dtype: float64

# %% [markdown]
# ## Filtrowanie Danych

# %%
pos = df[df.Daily_Change > 0]

# %%
neg = df[df.Daily_Change < 0]

# %%
pos.Daily_Change.mean()
# Out:
# 0.027955839591095308
